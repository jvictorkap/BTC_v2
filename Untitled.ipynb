# %%
import requests
import pandas as pd
import datetime
import urllib3
import DB
import DB
import workdays
import datetime 
import pandas as pd
import numpy as np

holidays_br = workdays.load_holidays('BR')
holidays_b3 = workdays.load_holidays('B3')


dt = datetime.date.today()
vcto_0 = dt.strftime('%d/%m/%Y')

dt_1 = workdays.workday(dt, -1, holidays_b3)

dt_30 = workdays.workday(dt, 30, holidays_b3)



DB.get_alugueis(dt_1,dt_30)
# Out:
#                      contrato    registro             corretora  \
# 0    2021120100317905400001-1  2021-12-01  UBS BRASIL CCTVM S/A
# 1    2021120200318184600001-1  2021-12-02  UBS BRASIL CCTVM S/A
# 2    2021120600318718430001-1  2021-12-06  UBS BRASIL CCTVM S/A
# 3    2021120700318937310001-1  2021-12-07  UBS BRASIL CCTVM S/A
# 4    2021120700318937370001-1  2021-12-07  UBS BRASIL CCTVM S/A
# ..                        ...         ...                   ...
# 519  2021112500308385970001-2  2021-11-25           ITAU CV S/A
# 520  2021120800319086960001-1  2021-12-08  UBS BRASIL CCTVM S/A
# 521  2021120800319086990001-1  2021-12-08  UBS BRASIL CCTVM S/A
# 522  2021120900319263850001-1  2021-12-09  UBS BRASIL CCTVM S/A
# 523  2021121000319434480001-1  2021-12-10  UBS BRASIL CCTVM S/A
#
#                          fundo reversor  codigo  vencimento    taxa  \
# 0    KAPITALO KAPPA MASTER FIM       TD   ABEV3  2022-01-12  0.0040
# 1    KAPITALO KAPPA MASTER FIM       TD   ABEV3  2022-01-13  0.0040
# 2    KAPITALO KAPPA MASTER FIM       TD   ABEV3  2022-01-17  0.0036
# 3    KAPITALO KAPPA MASTER FIM       TD   ABEV3  2022-01-18  0.0041
# 4    KAPITALO KAPPA MASTER FIM       TD   ABEV3  2022-01-18  0.0041
# ..                         ...      ...     ...         ...     ...
# 519  KAPITALO KAPPA MASTER FIM       TD  XPBR31  2021-12-28  0.0540
# 520  KAPITALO KAPPA MASTER FIM       TD   YDUQ3  2022-01-19  0.0080
# 521  KAPITALO KAPPA MASTER FIM       TD   YDUQ3  2022-01-19  0.0080
# 522  KAPITALO KAPPA MASTER FIM       TD   YDUQ3  2022-01-20  0.0080
# 523  KAPITALO KAPPA MASTER FIM       TD   YDUQ3  2022-01-21  0.0080
#
#      quantidade  preco_init  negeletr tipo
# 0      -68900.0       16.10     False    D
# 1      -13707.0       15.85     False    D
# 2      -12700.0       16.03     False    D
# 3       -8600.0       16.16     False    D
# 4       -9500.0       16.16     False    D
# ..          ...         ...       ...  ...
# 519       161.0      168.76     False    T
# 520     -6900.0       24.05     False    D
# 521    -10700.0       24.05     False    D
# 522      -405.0       24.28     False    D
# 523     -1300.0       23.69     False    D
#
# [524 rows x 12 columns]
